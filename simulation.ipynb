# %%
# !apt-get install -y cuda-toolkit-12-3
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   at-spi2-core cuda-cccl-12-3 cuda-command-line-tools-12-3 cuda-compiler-12-3
#   cuda-crt-12-3 cuda-cudart-12-3 cuda-cudart-dev-12-3 cuda-cuobjdump-12-3
#   cuda-cupti-12-3 cuda-cupti-dev-12-3 cuda-cuxxfilt-12-3
#   cuda-documentation-12-3 cuda-driver-dev-12-3 cuda-gdb-12-3
#   cuda-libraries-12-3 cuda-libraries-dev-12-3 cuda-nsight-12-3
#   cuda-nsight-compute-12-3 cuda-nsight-systems-12-3 cuda-nvcc-12-3
#   cuda-nvdisasm-12-3 cuda-nvml-dev-12-3 cuda-nvprof-12-3 cuda-nvprune-12-3
#   cuda-nvrtc-12-3 cuda-nvrtc-dev-12-3 cuda-nvtx-12-3 cuda-nvvm-12-3
#   cuda-nvvp-12-3 cuda-opencl-12-3 cuda-opencl-dev-12-3 cuda-profiler-api-12-3
#   cuda-sanitizer-12-3 cuda-toolkit-12-3-config-common cuda-tools-12-3
#   cuda-visual-tools-12-3 default-jre default-jre-headless fonts-dejavu-core
#   fonts-dejavu-extra gds-tools-12-3 gsettings-desktop-schemas
#   libatk-bridge2.0-0 libatk-wrapper-java libatk-wrapper-java-jni libatk1.0-0
#   libatk1.0-data libatspi2.0-0 libcublas-12-3 libcublas-dev-12-3 libcufft-12-3
#   libcufft-dev-12-3 libcufile-12-3 libcufile-dev-12-3 libcurand-12-3
#   libcurand-dev-12-3 libcusolver-12-3 libcusolver-dev-12-3 libcusparse-12-3
#   libcusparse-dev-12-3 libnpp-12-3 libnpp-dev-12-3 libnvjitlink-12-3
#   libnvjitlink-dev-12-3 libnvjpeg-12-3 libnvjpeg-dev-12-3 libtinfo5
#   libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0 libxcb-util1
#   libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxcomposite1
#   libxkbcommon-x11-0 libxtst6 libxxf86dga1 nsight-compute-2023.3.1
#   nsight-systems-2023.3.3 openjdk-11-jre openjdk-11-jre-headless
#   session-migration x11-utils
# Suggested packages:
#   libnss-mdns fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   | fonts-wqy-zenhei fonts-indic mesa-utils
# The following NEW packages will be installed:
#   at-spi2-core cuda-cccl-12-3 cuda-command-line-tools-12-3 cuda-compiler-12-3
#   cuda-crt-12-3 cuda-cudart-12-3 cuda-cudart-dev-12-3 cuda-cuobjdump-12-3
#   cuda-cupti-12-3 cuda-cupti-dev-12-3 cuda-cuxxfilt-12-3
#   cuda-documentation-12-3 cuda-driver-dev-12-3 cuda-gdb-12-3
#   cuda-libraries-12-3 cuda-libraries-dev-12-3 cuda-nsight-12-3
#   cuda-nsight-compute-12-3 cuda-nsight-systems-12-3 cuda-nvcc-12-3
#   cuda-nvdisasm-12-3 cuda-nvml-dev-12-3 cuda-nvprof-12-3 cuda-nvprune-12-3
#   cuda-nvrtc-12-3 cuda-nvrtc-dev-12-3 cuda-nvtx-12-3 cuda-nvvm-12-3
#   cuda-nvvp-12-3 cuda-opencl-12-3 cuda-opencl-dev-12-3 cuda-profiler-api-12-3
#   cuda-sanitizer-12-3 cuda-toolkit-12-3 cuda-toolkit-12-3-config-common
#   cuda-tools-12-3 cuda-visual-tools-12-3 default-jre default-jre-headless
#   fonts-dejavu-core fonts-dejavu-extra gds-tools-12-3
#   gsettings-desktop-schemas libatk-bridge2.0-0 libatk-wrapper-java
#   libatk-wrapper-java-jni libatk1.0-0 libatk1.0-data libatspi2.0-0
#   libcublas-12-3 libcublas-dev-12-3 libcufft-12-3 libcufft-dev-12-3
#   libcufile-12-3 libcufile-dev-12-3 libcurand-12-3 libcurand-dev-12-3
#   libcusolver-12-3 libcusolver-dev-12-3 libcusparse-12-3 libcusparse-dev-12-3
#   libnpp-12-3 libnpp-dev-12-3 libnvjitlink-12-3 libnvjitlink-dev-12-3
#   libnvjpeg-12-3 libnvjpeg-dev-12-3 libtinfo5 libxcb-icccm4 libxcb-image0
#   libxcb-keysyms1 libxcb-render-util0 libxcb-util1 libxcb-xinerama0
#   libxcb-xinput0 libxcb-xkb1 libxcomposite1 libxkbcommon-x11-0 libxtst6
#   libxxf86dga1 nsight-compute-2023.3.1 nsight-systems-2023.3.3 openjdk-11-jre
#   openjdk-11-jre-headless session-migration x11-utils
# 0 upgraded, 86 newly installed, 0 to remove and 37 not upgraded.
# Need to get 2,890 MB of archives.
# After this operation, 6,636 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 at-spi2-core amd64 2.44.0-3 [54.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre-headless amd64 11.0.30+7-1ubuntu1~22.04 [42.6 MB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cccl-12-3 12.3.101-1 [1,187 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-12-3 12.3.101-1 [16.9 MB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-dev-12-3 12.3.101-1 [2,604 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.30+7-1ubuntu1~22.04 [214 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libtinfo5 amd64 6.3-2ubuntu0.1 [100 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:21 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvdisasm-12-3 12.3.101-1 [49.9 MB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:34 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuobjdump-12-3 12.3.101-1 [175 kB]
# Get:35 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-gdb-12-3 12.3.101-1 [4,569 kB]
# Get:36 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprof-12-3 12.3.101-1 [2,439 kB]
# Get:37 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvtx-12-3 12.3.101-1 [51.4 kB]
# Get:38 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-sanitizer-12-3 12.3.101-1 [9,122 kB]
# Get:39 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-command-line-tools-12-3 12.3.2-1 [2,542 B]
# Get:40 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuxxfilt-12-3 12.3.101-1 [190 kB]
# Get:41 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-12-3-config-common 12.3.101-1 [16.3 kB]
# Get:42 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-12-3 12.3.101-1 [164 kB]
# Get:43 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-driver-dev-12-3 12.3.101-1 [28.3 kB]
# Get:44 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-dev-12-3 12.3.101-1 [993 kB]
# Get:45 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvvm-12-3 12.3.107-1 [19.3 MB]
# Get:46 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-crt-12-3 12.3.107-1 [77.4 kB]
# Get:47 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvcc-12-3 12.3.107-1 [28.6 MB]
# Get:48 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprune-12-3 12.3.101-1 [58.6 kB]
# Get:49 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-compiler-12-3 12.3.2-1 [2,510 B]
# Get:50 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-documentation-12-3 12.3.101-1 [49.9 kB]
# Get:51 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-12-3 12.3.107-1 [17.6 MB]
# Get:52 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-opencl-12-3 12.3.101-1 [23.8 kB]
# Get:53 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-12-3 12.3.4.1-1 [244 MB]
# Get:54 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-12-3 11.0.12.1-1 [58.6 MB]
# Get:55 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-12-3 1.8.1.2-1 [852 kB]
# Get:56 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-12-3 10.3.4.107-1 [41.3 MB]
# Get:57 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-12-3 11.5.4.101-1 [77.6 MB]
# Get:58 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-12-3 12.2.0.103-1 [109 MB]
# Get:59 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-12-3 12.2.3.2-1 [97.0 MB]
# Get:60 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjitlink-12-3 12.3.101-1 [15.1 MB]
# Get:61 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-12-3 12.3.0.81-1 [2,330 kB]
# Get:62 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-12-3 12.3.2-1 [2,602 B]
# Get:63 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-profiler-api-12-3 12.3.101-1 [18.5 kB]
# Get:64 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-dev-12-3 12.3.107-1 [14.5 MB]
# Get:65 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-opencl-dev-12-3 12.3.101-1 [71.1 kB]
# Get:66 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-dev-12-3 12.3.4.1-1 [270 MB]
# Get:67 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-dev-12-3 11.0.12.1-1 [117 MB]
# Get:68 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-dev-12-3 1.8.1.2-1 [2,432 kB]
# Get:69 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-dev-12-3 10.3.4.107-1 [41.7 MB]
# Get:70 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-dev-12-3 11.5.4.101-1 [48.8 MB]
# Get:71 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-dev-12-3 12.2.0.103-1 [113 MB]
# Get:72 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-dev-12-3 12.2.3.2-1 [94.2 MB]
# Get:73 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjitlink-dev-12-3 12.3.101-1 [11.7 MB]
# Get:74 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-dev-12-3 12.3.0.81-1 [2,029 kB]
# Get:75 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-dev-12-3 12.3.2-1 [2,642 B]
# Get:76 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-12-3 12.3.101-1 [119 MB]
# Get:77 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-compute-2023.3.1 2023.3.1.1-1 [733 MB]
# Get:78 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-compute-12-3 12.3.2-1 [4,052 B]
# Get:79 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-systems-2023.3.3 2023.3.3.42-233333266658v0 [324 MB]
# Get:80 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-systems-12-3 12.3.2-1 [3,352 B]
# Get:81 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvml-dev-12-3 12.3.101-1 [89.6 kB]
# Get:82 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvvp-12-3 12.3.101-1 [113 MB]
# Get:83 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-visual-tools-12-3 12.3.2-1 [2,946 B]
# Get:84 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  gds-tools-12-3 1.8.1.2-1 [39.1 MB]
# Get:85 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-tools-12-3 12.3.2-1 [2,462 B]
# Get:86 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-12-3 12.3.2-1 [3,276 B]
# Fetched 2,890 MB in 2min 9s (22.3 MB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libatspi2.0-0:amd64.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../00-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../01-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../02-session-migration_0.3.6_amd64.deb ...
# Unpacking session-migration (0.3.6) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../03-gsettings-desktop-schemas_42.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../04-at-spi2-core_2.44.0-3_amd64.deb ...
# Unpacking at-spi2-core (2.44.0-3) ...
# Selecting previously unselected package cuda-cccl-12-3.
# Preparing to unpack .../05-cuda-cccl-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-cccl-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-cupti-12-3.
# Preparing to unpack .../06-cuda-cupti-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-cupti-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-cupti-dev-12-3.
# Preparing to unpack .../07-cuda-cupti-dev-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-cupti-dev-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-nvdisasm-12-3.
# Preparing to unpack .../08-cuda-nvdisasm-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-nvdisasm-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-cuobjdump-12-3.
# Preparing to unpack .../09-cuda-cuobjdump-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-cuobjdump-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-gdb-12-3.
# Preparing to unpack .../10-cuda-gdb-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-gdb-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-nvprof-12-3.
# Preparing to unpack .../11-cuda-nvprof-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-nvprof-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-nvtx-12-3.
# Preparing to unpack .../12-cuda-nvtx-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-nvtx-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-sanitizer-12-3.
# Preparing to unpack .../13-cuda-sanitizer-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-sanitizer-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-command-line-tools-12-3.
# Preparing to unpack .../14-cuda-command-line-tools-12-3_12.3.2-1_amd64.deb ...
# Unpacking cuda-command-line-tools-12-3 (12.3.2-1) ...
# Selecting previously unselected package cuda-cuxxfilt-12-3.
# Preparing to unpack .../15-cuda-cuxxfilt-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-cuxxfilt-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-toolkit-12-3-config-common.
# Preparing to unpack .../16-cuda-toolkit-12-3-config-common_12.3.101-1_all.deb ...
# Unpacking cuda-toolkit-12-3-config-common (12.3.101-1) ...
# Selecting previously unselected package cuda-cudart-12-3.
# Preparing to unpack .../17-cuda-cudart-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-cudart-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-driver-dev-12-3.
# Preparing to unpack .../18-cuda-driver-dev-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-driver-dev-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-cudart-dev-12-3.
# Preparing to unpack .../19-cuda-cudart-dev-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-cudart-dev-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-nvvm-12-3.
# Preparing to unpack .../20-cuda-nvvm-12-3_12.3.107-1_amd64.deb ...
# Unpacking cuda-nvvm-12-3 (12.3.107-1) ...
# Selecting previously unselected package cuda-crt-12-3.
# Preparing to unpack .../21-cuda-crt-12-3_12.3.107-1_amd64.deb ...
# Unpacking cuda-crt-12-3 (12.3.107-1) ...
# Selecting previously unselected package cuda-nvcc-12-3.
# Preparing to unpack .../22-cuda-nvcc-12-3_12.3.107-1_amd64.deb ...
# Unpacking cuda-nvcc-12-3 (12.3.107-1) ...
# Selecting previously unselected package cuda-nvprune-12-3.
# Preparing to unpack .../23-cuda-nvprune-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-nvprune-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-compiler-12-3.
# Preparing to unpack .../24-cuda-compiler-12-3_12.3.2-1_amd64.deb ...
# Unpacking cuda-compiler-12-3 (12.3.2-1) ...
# Selecting previously unselected package cuda-documentation-12-3.
# Preparing to unpack .../25-cuda-documentation-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-documentation-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-nvrtc-12-3.
# Preparing to unpack .../26-cuda-nvrtc-12-3_12.3.107-1_amd64.deb ...
# Unpacking cuda-nvrtc-12-3 (12.3.107-1) ...
# Selecting previously unselected package cuda-opencl-12-3.
# Preparing to unpack .../27-cuda-opencl-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-opencl-12-3 (12.3.101-1) ...
# Selecting previously unselected package libcublas-12-3.
# Preparing to unpack .../28-libcublas-12-3_12.3.4.1-1_amd64.deb ...
# Unpacking libcublas-12-3 (12.3.4.1-1) ...
# Selecting previously unselected package libcufft-12-3.
# Preparing to unpack .../29-libcufft-12-3_11.0.12.1-1_amd64.deb ...
# Unpacking libcufft-12-3 (11.0.12.1-1) ...
# Selecting previously unselected package libcufile-12-3.
# Preparing to unpack .../30-libcufile-12-3_1.8.1.2-1_amd64.deb ...
# Unpacking libcufile-12-3 (1.8.1.2-1) ...
# Selecting previously unselected package libcurand-12-3.
# Preparing to unpack .../31-libcurand-12-3_10.3.4.107-1_amd64.deb ...
# Unpacking libcurand-12-3 (10.3.4.107-1) ...
# Selecting previously unselected package libcusolver-12-3.
# Preparing to unpack .../32-libcusolver-12-3_11.5.4.101-1_amd64.deb ...
# Unpacking libcusolver-12-3 (11.5.4.101-1) ...
# Selecting previously unselected package libcusparse-12-3.
# Preparing to unpack .../33-libcusparse-12-3_12.2.0.103-1_amd64.deb ...
# Unpacking libcusparse-12-3 (12.2.0.103-1) ...
# Selecting previously unselected package libnpp-12-3.
# Preparing to unpack .../34-libnpp-12-3_12.2.3.2-1_amd64.deb ...
# Unpacking libnpp-12-3 (12.2.3.2-1) ...
# Selecting previously unselected package libnvjitlink-12-3.
# Preparing to unpack .../35-libnvjitlink-12-3_12.3.101-1_amd64.deb ...
# Unpacking libnvjitlink-12-3 (12.3.101-1) ...
# Selecting previously unselected package libnvjpeg-12-3.
# Preparing to unpack .../36-libnvjpeg-12-3_12.3.0.81-1_amd64.deb ...
# Unpacking libnvjpeg-12-3 (12.3.0.81-1) ...
# Selecting previously unselected package cuda-libraries-12-3.
# Preparing to unpack .../37-cuda-libraries-12-3_12.3.2-1_amd64.deb ...
# Unpacking cuda-libraries-12-3 (12.3.2-1) ...
# Selecting previously unselected package cuda-profiler-api-12-3.
# Preparing to unpack .../38-cuda-profiler-api-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-profiler-api-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-12-3.
# Preparing to unpack .../39-cuda-nvrtc-dev-12-3_12.3.107-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-12-3 (12.3.107-1) ...
# Selecting previously unselected package cuda-opencl-dev-12-3.
# Preparing to unpack .../40-cuda-opencl-dev-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-opencl-dev-12-3 (12.3.101-1) ...
# Selecting previously unselected package libcublas-dev-12-3.
# Preparing to unpack .../41-libcublas-dev-12-3_12.3.4.1-1_amd64.deb ...
# Unpacking libcublas-dev-12-3 (12.3.4.1-1) ...
# Selecting previously unselected package libcufft-dev-12-3.
# Preparing to unpack .../42-libcufft-dev-12-3_11.0.12.1-1_amd64.deb ...
# Unpacking libcufft-dev-12-3 (11.0.12.1-1) ...
# Selecting previously unselected package libcufile-dev-12-3.
# Preparing to unpack .../43-libcufile-dev-12-3_1.8.1.2-1_amd64.deb ...
# Unpacking libcufile-dev-12-3 (1.8.1.2-1) ...
# Selecting previously unselected package libcurand-dev-12-3.
# Preparing to unpack .../44-libcurand-dev-12-3_10.3.4.107-1_amd64.deb ...
# Unpacking libcurand-dev-12-3 (10.3.4.107-1) ...
# Selecting previously unselected package libcusolver-dev-12-3.
# Preparing to unpack .../45-libcusolver-dev-12-3_11.5.4.101-1_amd64.deb ...
# Unpacking libcusolver-dev-12-3 (11.5.4.101-1) ...
# Selecting previously unselected package libcusparse-dev-12-3.
# Preparing to unpack .../46-libcusparse-dev-12-3_12.2.0.103-1_amd64.deb ...
# Unpacking libcusparse-dev-12-3 (12.2.0.103-1) ...
# Selecting previously unselected package libnpp-dev-12-3.
# Preparing to unpack .../47-libnpp-dev-12-3_12.2.3.2-1_amd64.deb ...
# Unpacking libnpp-dev-12-3 (12.2.3.2-1) ...
# Selecting previously unselected package libnvjitlink-dev-12-3.
# Preparing to unpack .../48-libnvjitlink-dev-12-3_12.3.101-1_amd64.deb ...
# Unpacking libnvjitlink-dev-12-3 (12.3.101-1) ...
# Selecting previously unselected package libnvjpeg-dev-12-3.
# Preparing to unpack .../49-libnvjpeg-dev-12-3_12.3.0.81-1_amd64.deb ...
# Unpacking libnvjpeg-dev-12-3 (12.3.0.81-1) ...
# Selecting previously unselected package cuda-libraries-dev-12-3.
# Preparing to unpack .../50-cuda-libraries-dev-12-3_12.3.2-1_amd64.deb ...
# Unpacking cuda-libraries-dev-12-3 (12.3.2-1) ...
# Selecting previously unselected package openjdk-11-jre-headless:amd64.
# Preparing to unpack .../51-openjdk-11-jre-headless_11.0.30+7-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre-headless:amd64 (11.0.30+7-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../52-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../53-openjdk-11-jre_11.0.30+7-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.30+7-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../54-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package cuda-nsight-12-3.
# Preparing to unpack .../55-cuda-nsight-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-nsight-12-3 (12.3.101-1) ...
# Selecting previously unselected package nsight-compute-2023.3.1.
# Preparing to unpack .../56-nsight-compute-2023.3.1_2023.3.1.1-1_amd64.deb ...
# Unpacking nsight-compute-2023.3.1 (2023.3.1.1-1) ...
# Selecting previously unselected package cuda-nsight-compute-12-3.
# Preparing to unpack .../57-cuda-nsight-compute-12-3_12.3.2-1_amd64.deb ...
# Unpacking cuda-nsight-compute-12-3 (12.3.2-1) ...
# Selecting previously unselected package libtinfo5:amd64.
# Preparing to unpack .../58-libtinfo5_6.3-2ubuntu0.1_amd64.deb ...
# Unpacking libtinfo5:amd64 (6.3-2ubuntu0.1) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../59-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../60-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../61-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../62-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../63-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../64-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../65-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../66-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../67-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../68-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package nsight-systems-2023.3.3.
# Preparing to unpack .../69-nsight-systems-2023.3.3_2023.3.3.42-233333266658v0_amd64.deb ...
# Unpacking nsight-systems-2023.3.3 (2023.3.3.42-233333266658v0) ...
# Selecting previously unselected package cuda-nsight-systems-12-3.
# Preparing to unpack .../70-cuda-nsight-systems-12-3_12.3.2-1_amd64.deb ...
# Unpacking cuda-nsight-systems-12-3 (12.3.2-1) ...
# Selecting previously unselected package cuda-nvml-dev-12-3.
# Preparing to unpack .../71-cuda-nvml-dev-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-nvml-dev-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-nvvp-12-3.
# Preparing to unpack .../72-cuda-nvvp-12-3_12.3.101-1_amd64.deb ...
# Unpacking cuda-nvvp-12-3 (12.3.101-1) ...
# Selecting previously unselected package cuda-visual-tools-12-3.
# Preparing to unpack .../73-cuda-visual-tools-12-3_12.3.2-1_amd64.deb ...
# Unpacking cuda-visual-tools-12-3 (12.3.2-1) ...
# Selecting previously unselected package gds-tools-12-3.
# Preparing to unpack .../74-gds-tools-12-3_1.8.1.2-1_amd64.deb ...
# Unpacking gds-tools-12-3 (1.8.1.2-1) ...
# Selecting previously unselected package cuda-tools-12-3.
# Preparing to unpack .../75-cuda-tools-12-3_12.3.2-1_amd64.deb ...
# Unpacking cuda-tools-12-3 (12.3.2-1) ...
# Selecting previously unselected package cuda-toolkit-12-3.
# Preparing to unpack .../76-cuda-toolkit-12-3_12.3.2-1_amd64.deb ...
# Unpacking cuda-toolkit-12-3 (12.3.2-1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../77-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../78-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../79-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../80-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../81-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../82-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../83-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../84-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../85-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up cuda-profiler-api-12-3 (12.3.101-1) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up nsight-compute-2023.3.1 (2023.3.1.1-1) ...
# Setting up cuda-cuxxfilt-12-3 (12.3.101-1) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-cccl-12-3 (12.3.101-1) ...
# Setting up cuda-nvdisasm-12-3 (12.3.101-1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up cuda-nvtx-12-3 (12.3.101-1) ...
# Setting up openjdk-11-jre-headless:amd64 (11.0.30+7-1ubuntu1~22.04) ...
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/jjs to provide /usr/bin/jjs (jjs) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/rmid to provide /usr/bin/rmid (rmid) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/pack200 to provide /usr/bin/pack200 (pack200) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/unpack200 to provide /usr/bin/unpack200 (unpack200) in auto mode
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up cuda-nsight-compute-12-3 (12.3.2-1) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up openjdk-11-jre:amd64 (11.0.30+7-1ubuntu1~22.04) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up gds-tools-12-3 (1.8.1.2-1) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up cuda-cuobjdump-12-3 (12.3.101-1) ...
# Setting up cuda-nvrtc-12-3 (12.3.107-1) ...
# Setting up cuda-sanitizer-12-3 (12.3.101-1) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-nvvm-12-3 (12.3.107-1) ...
# Setting up cuda-cupti-12-3 (12.3.101-1) ...
# Setting up cuda-toolkit-12-3-config-common (12.3.101-1) ...
# Setting alternatives
# Setting up cuda-nvprof-12-3 (12.3.101-1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up libcublas-12-3 (12.3.4.1-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up cuda-gdb-12-3 (12.3.101-1) ...
# Setting up libnpp-12-3 (12.2.3.2-1) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up libnvjitlink-12-3 (12.3.101-1) ...
# Setting up cuda-nvml-dev-12-3 (12.3.101-1) ...
# Setting up cuda-opencl-12-3 (12.3.101-1) ...
# Setting up libtinfo5:amd64 (6.3-2ubuntu0.1) ...
# Setting up libcurand-12-3 (10.3.4.107-1) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up cuda-nvprune-12-3 (12.3.101-1) ...
# Setting up cuda-documentation-12-3 (12.3.101-1) ...
# Setting up cuda-driver-dev-12-3 (12.3.101-1) ...
# Setting up libnvjitlink-dev-12-3 (12.3.101-1) ...
# Setting up cuda-nvrtc-dev-12-3 (12.3.107-1) ...
# Setting up nsight-systems-2023.3.3 (2023.3.3.42-233333266658v0) ...
# update-alternatives: using /opt/nvidia/nsight-systems/2023.3.3/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2023.3.3/host-linux-x64/nsys-ui to provide /usr/local/bin/nsys-ui (nsys-ui) in auto mode
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up cuda-nsight-systems-12-3 (12.3.2-1) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up libcurand-dev-12-3 (10.3.4.107-1) ...
# Setting up libcublas-dev-12-3 (12.3.4.1-1) ...
# Setting up cuda-cudart-12-3 (12.3.101-1) ...
# Setting up libnvjpeg-12-3 (12.3.0.81-1) ...
# Setting up libcusolver-12-3 (11.5.4.101-1) ...
# Setting up libcufft-12-3 (11.0.12.1-1) ...
# Setting up libcufile-12-3 (1.8.1.2-1) ...
# Setting alternatives
# Setting up default-jre (2:1.11-72build2) ...
# Setting up libnvjpeg-dev-12-3 (12.3.0.81-1) ...
# Setting up libcusparse-12-3 (12.2.0.103-1) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up libcufile-dev-12-3 (1.8.1.2-1) ...
# Setting up cuda-nsight-12-3 (12.3.101-1) ...
# Setting up cuda-cupti-dev-12-3 (12.3.101-1) ...
# Setting up cuda-cudart-dev-12-3 (12.3.101-1) ...
# Setting up cuda-opencl-dev-12-3 (12.3.101-1) ...
# Setting up libnpp-dev-12-3 (12.2.3.2-1) ...
# Setting up cuda-command-line-tools-12-3 (12.3.2-1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libcufft-dev-12-3 (11.0.12.1-1) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up cuda-libraries-12-3 (12.3.2-1) ...
# Setting up libcusolver-dev-12-3 (11.5.4.101-1) ...
# Setting up cuda-nvvp-12-3 (12.3.101-1) ...
# Setting up cuda-crt-12-3 (12.3.107-1) ...
# Setting up libcusparse-dev-12-3 (12.2.0.103-1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up cuda-nvcc-12-3 (12.3.107-1) ...
# Setting up cuda-compiler-12-3 (12.3.2-1) ...
# Setting up cuda-libraries-dev-12-3 (12.3.2-1) ...
# Setting up cuda-visual-tools-12-3 (12.3.2-1) ...
# Setting up cuda-tools-12-3 (12.3.2-1) ...
# Setting up cuda-toolkit-12-3 (12.3.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.9) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Setting up at-spi2-core (2.44.0-3) ...

# %%
# !pip install nvcc4jupyter
# Out:
# Collecting nvcc4jupyter
#   Downloading nvcc4jupyter-1.2.1-py3-none-any.whl.metadata (5.1 kB)
# Downloading nvcc4jupyter-1.2.1-py3-none-any.whl (10 kB)
# Installing collected packages: nvcc4jupyter
# Successfully installed nvcc4jupyter-1.2.1

# %%
# !python --version
# !nvcc --version
# %load_ext nvcc4jupyter

# !rm -f /usr/local/cuda
# !ln -s /usr/local/cuda-12.3 /usr/local/cuda
# Out:
# Python 3.12.12
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Fri_Feb_21_20:23:50_PST_2025
# Cuda compilation tools, release 12.8, V12.8.93
# Build cuda_12.8.r12.8/compiler.35583870_0
# Detected platform "Colab". Running its setup...
# Source files will be saved in "/tmp/tmp0jytiww_".

# %%
# %%cuda -arch=compute_86
# // serial cpp code
# #include <cuda_runtime.h>
# #include <stdio.h>
# #include <random>
# #include <iostream>
# #include <chrono>
# #include <iomanip>
#
# int simulation(int* circle_points, int* square_points, int N, std::mt19937& gen, std::uniform_real_distribution<float>& dis) {
#     float x, y;
#     for (int n = 0; n < N; ++n) {
#         x = dis(gen);
#         y = dis(gen);
#         if (x*x + y*y <= 1)
#             (*circle_points)++;
#         else
#           (*square_points)++;
#     }
# }
#
# int main() {
#     // random number generator
#     //std::random_device rd;  // Will be used to obtain a seed for the random number engine
#     int seed = 12; // set seed
#     std::mt19937 gen(seed); // Standard mersenne_twister_engine seeded with rd()
#     std::uniform_real_distribution<float> dis(-1.0, 1.0);
#
#     // declare values
#     int N = 1e7;  // number of simulations
#     int circle_points;
#     int square_points;
#     circle_points = 0;
#     square_points = 0;
#
#     const auto start = std::chrono::high_resolution_clock::now();
#
#     simulation(&circle_points, &square_points, N, gen, dis);
#
#     const auto end = std::chrono::high_resolution_clock::now();
#
#     std::chrono::duration<double, std::milli> elapsed_ms = end - start;
#
#     float pi = 4.0f * static_cast<float>(circle_points) / (circle_points + square_points);
#
#     std::cout << std::setprecision(std::numeric_limits<double>::max_digits10);
#
#     std::cout << "pi = " << pi << " | Simulations = " << N << " | elapsed time(ms) " << elapsed_ms.count() << std::endl;
#     return 0;
# }
# Out:
# pi = 3.1422750949859619 | Simulations = 10000000 | elapsed time(ms) 958.116443

# %%
# %%writefile monte_carlo.cu
#
# #include <cuda_runtime.h>
# #include <stdio.h>
# #include <random>
# #include <iostream>
# #include <curand.h>
#
# __global__
# void compute(int* circle_points, int* square_points, size_t N, float* xVec, float* yVec, int unrolls) {
#     __shared__ int s_circle;
#     __shared__ int s_square; // use shared memory for less overhead
#     if (threadIdx.x == 0) {
#         s_circle = 0;
#         s_square = 0;
#     }
#     __syncthreads();
#
#     size_t idx = blockIdx.x * blockDim.x * unrolls + threadIdx.x;
#     size_t i;
#     int localC = 0;
#     int localS = 0;
#
#     #pragma unroll 16
#     for (int n = 0; n < unrolls; n++) {
#         i = idx + n * blockDim.x;
#         if (i < N) {
#             float x = xVec[i];
#             float y = yVec[i];
#             if (x*x + y*y <= 1)
#                 localC++;
#             else
#                 localS++;
#         }
#     }
#     atomicAdd(&s_circle, localC); // added to shared memory
#     atomicAdd(&s_square, localS);
#     __syncthreads();
#
#     if (threadIdx.x == 0) {
#         atomicAdd(circle_points, s_circle);
#         atomicAdd(square_points, s_square);
#     }
# }
#
# void simulation(int* circle_points, int* square_points, size_t N, curandGenerator_t& generator, float* xVec, float* yVec) {
#     // standard real mersenne float monte carlo distribution
#     curandGenerateUniform(generator, xVec, N);
#     curandGenerateUniform(generator, yVec, N);
#     int threads = 256;
#     int unrolls = 8;
#     int blocks = (N + threads * unrolls -1)/(threads*unrolls);
#
#     compute<<<blocks, threads>>>(circle_points, square_points, N, xVec, yVec, unrolls);
#     cudaDeviceSynchronize(); // ensure GPU finishes before reading counters
#
# }
#
# float benchMark(int* circle_points, int* square_points, size_t N, curandGenerator_t& gen, float* xVec, float* yVec, bool flush) {
#     // cache flushing
#     int device = 0;
#     int l2_size = 0;
#     float* d_F;
#
#     cudaGetDevice(&device);
#     cudaDeviceGetAttribute(&l2_size, cudaDevAttrL2CacheSize, device);
#     size_t sizeF = l2_size * 2;
#
#     // benchmarking variables
#     cudaEvent_t start, stop;
#     cudaEventCreate(&start);
#     cudaEventCreate(&stop);
#
#     if (flush){
#         cudaMalloc((void **)&d_F, sizeF);
#         cudaMemsetAsync((void *)d_F, 0, sizeF);
#         cudaDeviceSynchronize();
#     }
#
#     cudaEventRecord(start, 0);
#     simulation(circle_points, square_points, N, gen, xVec, yVec);
#
#     cudaEventRecord(stop, 0);
#     cudaEventSynchronize(stop);
#     float milliseconds = 0;
#     cudaEventElapsedTime(&milliseconds, start, stop);
#
#     if (flush){
#         cudaFree(d_F);
#     }
#
#     cudaEventDestroy(start);
#     cudaEventDestroy(stop);
#     return milliseconds;
# }
#
# int main() {
#     size_t N = 10000000;
#
#     // Use regular device memory for counters instead of Unified Memory
#     int *d_circle_points, *d_square_points;
#     int h_circle_points = 0, h_square_points = 0;
#
#     float *xVec, *yVec;
#     float milliseconds;
#
#     // Allocate device memory for counters
#     cudaMalloc(&d_circle_points, sizeof(int));
#     cudaMalloc(&d_square_points, sizeof(int));
#     cudaMalloc(&xVec, N * sizeof(float));
#     cudaMalloc(&yVec, N * sizeof(float));
#
#     // Initialize counters on device
#     cudaMemset(d_circle_points, 0, sizeof(int));
#     cudaMemset(d_square_points, 0, sizeof(int));
#
#     // Random number generator setup
#     unsigned long long seed = 12;
#     curandGenerator_t generator;
#     curandCreateGenerator(&generator, CURAND_RNG_PSEUDO_MT19937);
#     curandSetPseudoRandomGeneratorSeed(generator, seed);
#
#     milliseconds = benchMark(d_circle_points, d_square_points, N, generator, xVec, yVec, false);
#
#     // Copy results back from device to host
#     cudaMemcpy(&h_circle_points, d_circle_points, sizeof(int), cudaMemcpyDeviceToHost);
#     cudaMemcpy(&h_square_points, d_square_points, sizeof(int), cudaMemcpyDeviceToHost);
#
#     float pi = 4.0f * static_cast<float>(h_circle_points) / (h_circle_points + h_square_points);
#
#     std::cout << "pi = " << pi << " | Simulations = " << N << " | elapsed time(ms) " << milliseconds << std::endl;
#
#     cudaFree(d_circle_points);
#     cudaFree(d_square_points);
#     cudaFree(xVec);
#     cudaFree(yVec);
#     curandDestroyGenerator(generator);
#
#     return 0;
# }
# Out:
# Overwriting monte_carlo.cu

# %%
# !nvcc -arch=compute_86 -code=sm_86 -o matmul3
# Out:
# nvcc fatal   : No input files specified; use option --help for more information

# %%
# !nvcc -arch=compute_75 -code=sm_75 monte_carlo.cu -o monte_carlo -lcurand

# %%
# !./monte_carlo
# Out:
# pi = 3.14145 | Simulations = 10000000 | elapsed time(ms) 204.666
